# %%
# import requests
# HEADERS = {
#      "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
#                   "AppleWebKit/537.36 (KHTML, like Gecko) "
#                   "Chrome/120.0.0.0 Safari/537.36",
#     "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
#     "Accept-Language": "en-US,en;q=0.9",
#     "Connection": "keep-alive",
# }
# from bs4 import BeautifulSoup
# res = requests.get("https://exam.ioe.tu.edu.np/notices?title=BE&start_date=&nep_start_date=&end_date=&nep_end_date=&notice_type=930",headers= HEADERS,verify=False, )
# soup = BeautifulSoup(res.content, 'html.parser')
# # print(soup.prettify())
# Out:
# c:\Users\ACER\OneDrive\Desktop\Python\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'exam.ioe.tu.edu.np'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Required meta tags -->
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://exam.ioe.tu.edu.np/assets/temp2/bootstrap/bootstrap.min.css" rel="stylesheet"/>
#   <link href="https://exam.ioe.tu.edu.np/assets/temp2/font/bootstrap-icons/font/bootstrap-icons.css" rel="stylesheet"/>
#   <link href="https://exam.ioe.tu.edu.np/assets/temp2/css/temp2.css" rel="stylesheet"/>
#   <link href="https://portal.tu.edu.np/medias/2026_01_05_10_45_37.jpg" rel="shortcut icon" type="image/x-icon"/>
#   <title>
# ...

# %%
# notices = soup.find_all("div", class_= "detail")
# dates = soup.find_all("div",class_="date")

# for t in notices:
#     for d in dates:
#         print(d)
#     print(t)

# %%
# #finding the new website notice
# notices_div= soup.find_all("div", class_="recent-post-wrapper shdow")
# for notice in notices_div:
#     dates= notice.find_all("div", class_="date")
#     for date in dates:
#         # print(date)
#         d=  date.find("span",class_="nep_date").text.strip()
#         title= notice.find("h5")
#         link = notice.find("a")["href"]
#         print({
#             "date":d,
#             "title": title,
#             "link":link
#         })
# Out:
# {'date': '2026-02-02', 'title': <h5>Result BE I Year II Part (New Course) Regular 2082 Bhadra</h5>, 'link': 'https://exam.ioe.tu.edu.np/notices/11364'}
# {'date': '2025-11-28', 'title': <h5>Retotaling Result: BE/BAR I &amp; II / I and IV/ II exam held on 2082 Shrawan</h5>, 'link': 'https://exam.ioe.tu.edu.np/notices/10916'}
# {'date': '2025-11-11', 'title': <h5>Result: BE/BAR I/I (Old Course) Back exam held on 2082 Shrawan</h5>, 'link': 'https://exam.ioe.tu.edu.np/notices/10915'}
# {'date': '2025-11-11', 'title': <h5>Result: BE/BAR II/I, IV/II(BGE), V/II(BAR) and Lateral Entry (Old Course) Back exam held on 2082 Shrawan</h5>, 'link': 'https://exam.ioe.tu.edu.np/notices/10914'}
# {'date': '2025-11-02', 'title': <h5>Result: BE/BAR IV/II (Old Course) Back exam held on 2082 Shrawan</h5>, 'link': 'https://exam.ioe.tu.edu.np/notices/10910'}

# %%
# table = soup.find("table", id="datatable")

# rows = table.tbody.find_all("tr")

# for row in rows:
#     tds = row.find_all("td")
#     # print(tds)
#     sno= tds[0].get_text(strip=True)

#     title_tag= tds[1].find("a")
#     # print(title_tag)
#     title = title_tag.get_text(strip=True)
#     pdf_link= title_tag["href"]

#     notice_date = tds[2].get_text(strip=True)

#     view_link = tds[3].find("a")["href"]

#     print({
#         "sno": sno,
#         "title": title,
#         "date": notice_date,
#         "pdf": pdf_link,
#         "view": view_link
#     })
# Out:
# {'sno': '1', 'title': 'Result: BAR IV  and V Year I Part Regular, 2082', 'date': 'Thursday, January 29, 2026', 'pdf': '/Images/NotificationsFile/35.6410292Result BAR 4th and 5th Year I Part 2082 web.pdf', 'view': '/Notice/Index/30780'}
# {'sno': '2', 'title': 'Result: M.Sc. II/II Thesis held on Mangsir, 2082', 'date': 'Monday, January 5, 2026', 'pdf': '/Images/NotificationsFile/03.1677680MSC Thesis Back Result.PDF', 'view': '/Notice/Index/30778'}
# {'sno': '3', 'title': 'Retotaling Result: I & II / I  and IV/ II exam held on 2082 Shrawan', 'date': 'Friday, November 28, 2025', 'pdf': '/Images/NotificationsFile/42.4748977Retotaling Result.pdf', 'view': '/Notice/Index/30777'}
# {'sno': '4', 'title': 'Result: BE/BAR I/I (Old Course) Back exam held on 2082 Shrawan', 'date': 'Tuesday, November 11, 2025', 'pdf': '/Images/NotificationsFile/29.9375123I-I Bacxk Exam.pdf', 'view': '/Notice/Index/30775'}
# ...
